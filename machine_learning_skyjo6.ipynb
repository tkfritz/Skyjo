# %%
#should suppress warnings
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

import numpy as np
import random as random
import scipy
#using simpleguitk for display, is not needed for computer game
import simpleguitk as simplegui
import time
#new ones
import pandas as pd
from xgboost import XGBRegressor
import os
#skyjo game classes and functions
from skyjo_functions4 import *
#own functions for machine learning
from ml_functions2 import *
#for plotting 
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# The different computer levels against each other. Testing the newest level 9 and then 11, first against the random level 0.
#
# Then again level 5 which seems to be the best previous level (or level 1 but both are rather similar anyway). Since level 5 gets sometime sin an infinite loope, level 6 is used instead.

# %%
 

names=('alpha','beta')
nature=('computer','computer')
levels=(9,6)
start_time=time.time()
nn=int(3000)
all_scores=np.zeros((7,nn))
for i in range(nn):
    print(f"running case {i}")
    scores,turns,last_player,output=skyjo_round(names,nature,levels,0,True,True,True)
    all_scores[0,i]=i
    all_scores[1:3,i]=scores
    all_scores[3,i]=turns
    all_scores[4,i]=np.argmin(scores)
    all_scores[5,i]=output[0,0]
    all_scores[6,i]=output[0,output.shape[1]-1]    
stop_time=time.time()
print(f"running time was {stop_time-start_time}")
print(all_scores.T)
np.savetxt("level9_level6_3000_0.txt",all_scores)
# Out:
# running case 0
# running case 1
# running case 2
# running case 3
# running case 4
# running case 5
# running case 6
# running case 7
# running case 8
# running case 9
# running case 10
# running case 11
# running case 12
# running case 13
# running case 14
# running case 15
# running case 16
# running case 17
# running case 18
# running case 19
# running case 20
# running case 21
# running case 22
# running case 23
# running case 24
# running case 25
# running case 26
# running case 27
# running case 28
# running case 29
# running case 30
# running case 31
# running case 32
# running case 33
# running case 34
# running case 35
# running case 36
# running case 37
# running case 38
# running case 39
# running case 40
# running case 41
# running case 42
# running case 43
# running case 44
# running case 45
# running case 46
# running case 47
# running case 48
# running case 49
# running case 50
# running case 51
# running case 52
# running case 53
# running case 54
# running case 55
# running case 56
# running case 57
# running case 58
# running case 59
# running case 60
# running case 61
# running case 62
# running case 63
# running case 64
# running case 65
# running case 66
# running case 67
# running case 68
# running case 69
# running case 70
# running case 71
# running case 72
# running case 73
# running case 74
# running case 75
# running case 76
# running case 77
# running case 78
# running case 79
# running case 80
# running case 81
# running case 82
# running case 83
# running case 84
# running case 85
# running case 86
# running case 87
# running case 88
# running case 89
# running case 90
# running case 91
# running case 92
# running case 93
# running case 94
# running case 95
# running case 96
# running case 97
# running case 98
# running case 99
# running case 100
# running case 101
# running case 102
# running case 103
# running case 104
# running case 105
# running case 106
# running case 107
# running case 108
# running case 109
# running case 110
# running case 111
# running case 112
# running case 113
# running case 114
# running case 115
# running case 116
# running case 117
# running case 118
# running case 119
# running case 120
# running case 121
# running case 122
# running case 123
# running case 124
# running case 125
# running case 126
# running case 127
# running case 128
# running case 129
# running case 130
# running case 131
# running case 132
# running case 133
# running case 134
# running case 135
# running case 136
# running case 137
# running case 138
# running case 139
# running case 140
# running case 141
# running case 142
# running case 143
# running case 144
# running case 145
# running case 146
# running case 147
# running case 148
# running case 149
# running case 150
# running case 151
# running case 152
# running case 153
# running case 154
# running case 155
# running case 156
# running case 157
# running case 158
# running case 159
# running case 160
# running case 161
# running case 162
# running case 163
# running case 164
# running case 165
# running case 166
# running case 167
# running case 168
# running case 169
# running case 170
# running case 171
# running case 172
# running case 173
# running case 174
# running case 175
# running case 176
# running case 177
# running case 178
# running case 179
# running case 180
# running case 181
# running case 182
# running case 183
# running case 184
# running case 185
# running case 186
# running case 187
# running case 188
# running case 189
# running case 190
# running case 191
# running case 192
# running case 193
# running case 194
# running case 195
# running case 196
# running case 197
# running case 198
# running case 199
# running case 200
# running case 201
# running case 202
# running case 203
# running case 204
# running case 205
# running case 206
# running case 207
# running case 208
# running case 209
# running case 210
# running case 211
# running case 212
# running case 213
# running case 214
# running case 215
# running case 216
# running case 217
# running case 218
# running case 219
# running case 220
# running case 221
# running case 222
# running case 223
# running case 224
# running case 225
# running case 226
# running case 227
# running case 228
# running case 229
# running case 230
# running case 231
# running case 232
# running case 233
# running case 234
# running case 235
# running case 236
# running case 237
# running case 238
# running case 239
# running case 240
# running case 241
# running case 242
# running case 243
# running case 244
# running case 245
# running case 246
# running case 247
# running case 248
# running case 249
# running case 250
# running case 251
# running case 252
# running case 253
# running case 254
# running case 255
# running case 256
# running case 257
# running case 258
# running case 259
# running case 260
# running case 261
# running case 262
# running case 263
# running case 264
# running case 265
# running case 266
# running case 267
# running case 268
# running case 269
# running case 270
# running case 271
# running case 272
# running case 273
# running case 274
# running case 275
# running case 276
# running case 277
# running case 278
# running case 279
# running case 280
# running case 281
# running case 282
# running case 283
# running case 284
# running case 285
# running case 286
# running case 287
# running case 288
# running case 289
# running case 290
# running case 291
# running case 292
# running case 293
# running case 294
# running case 295
# running case 296
# running case 297
# running case 298
# running case 299
# running case 300
# running case 301
# running case 302
# running case 303
# running case 304
# running case 305
# running case 306
# running case 307
# running case 308
# running case 309
# running case 310
# running case 311
# running case 312
# running case 313
# running case 314
# running case 315
# running case 316
# running case 317
# running case 318
# running case 319
# running case 320
# running case 321
# running case 322
# running case 323
# running case 324
# running case 325
# running case 326
# running case 327
# running case 328
# running case 329
# running case 330
# running case 331
# running case 332
# running case 333
# running case 334
# running case 335
# running case 336
# running case 337
# running case 338
# running case 339
# running case 340
# running case 341
# running case 342
# running case 343
# running case 344
# running case 345
# running case 346
# running case 347
# running case 348
# running case 349
# running case 350
# running case 351
# running case 352
# running case 353
# running case 354
# running case 355
# running case 356
# running case 357
# running case 358
# running case 359
# running case 360
# running case 361
# running case 362
# running case 363
# running case 364
# running case 365
# running case 366
# running case 367
# running case 368
# running case 369
# running case 370
# running case 371
# running case 372
# running case 373
# running case 374
# running case 375
# running case 376
# running case 377
# running case 378
# running case 379
# running case 380
# running case 381
# running case 382
# running case 383
# running case 384
# running case 385
# running case 386
# running case 387
# running case 388
# running case 389
# running case 390
# running case 391
# running case 392
# running case 393
# running case 394
# running case 395
# running case 396
# running case 397
# running case 398
# running case 399
# running case 400
# running case 401
# running case 402
# running case 403
# running case 404
# running case 405
# running case 406
# running case 407
# running case 408
# running case 409
# running case 410
# running case 411
# running case 412
# running case 413
# running case 414
# running case 415
# running case 416
# running case 417
# running case 418
# running case 419
# running case 420
# running case 421
# running case 422
# running case 423
# running case 424
# running case 425
# running case 426
# running case 427
# running case 428
# running case 429
# running case 430
# running case 431
# running case 432
# running case 433
# running case 434
# running case 435
# running case 436
# running case 437
# running case 438
# running case 439
# running case 440
# running case 441
# running case 442
# running case 443
# running case 444
# running case 445
# running case 446
# running case 447
# running case 448
# running case 449
# running case 450
# running case 451
# running case 452
# running case 453
# running case 454
# running case 455
# running case 456
# running case 457
# running case 458
# running case 459
# running case 460
# running case 461
# running case 462
# running case 463
# running case 464
# running case 465
# running case 466
# running case 467
# running case 468
# running case 469
# running case 470
# running case 471
# running case 472
# running case 473
# running case 474
# running case 475
# running case 476
# running case 477
# running case 478
# running case 479
# running case 480
# running case 481
# running case 482
# running case 483
# running case 484
# running case 485
# running case 486
# running case 487
# running case 488
# running case 489
# running case 490
# running case 491
# running case 492
# running case 493
# running case 494
# running case 495
# running case 496
# running case 497
# running case 498
# running case 499
# running case 500
# running case 501
# running case 502
# running case 503
# running case 504
# running case 505
# running case 506
# running case 507
# running case 508
# running case 509
# running case 510
# running case 511
# running case 512
# running case 513
# running case 514
# running case 515
# running case 516
# running case 517
# running case 518
# running case 519
# running case 520
# running case 521
# running case 522
# running case 523
# running case 524
# running case 525
# running case 526
# running case 527
# running case 528
# running case 529
# running case 530
# running case 531
# running case 532
# running case 533
# running case 534
# running case 535
# running case 536
# running case 537
# running case 538
# running case 539
# running case 540
# running case 541
# running case 542
# running case 543
# running case 544
# running case 545
# running case 546
# running case 547
# running case 548
# running case 549
# running case 550
# running case 551
# running case 552
# running case 553
# running case 554
# running case 555
# running case 556
# running case 557
# running case 558
# running case 559
# running case 560
# running case 561
# running case 562
# running case 563
# running case 564
# running case 565
# running case 566
# running case 567
# running case 568
# running case 569
# running case 570
# running case 571
# running case 572
# running case 573
# running case 574
# running case 575
# running case 576
# running case 577
# running case 578
# running case 579
# running case 580
# running case 581
# running case 582
# running case 583
# running case 584
# running case 585
# running case 586
# running case 587
# running case 588
# running case 589
# running case 590
# running case 591
# running case 592
# running case 593
# running case 594
# running case 595
# running case 596
# running case 597
# running case 598
# running case 599
# running case 600
# running case 601
# running case 602
# running case 603
# running case 604
# running case 605
# running case 606
# running case 607
# running case 608
# running case 609
# running case 610
# running case 611
# running case 612
# running case 613
# running case 614
# running case 615
# running case 616
# running case 617
# running case 618
# running case 619
# running case 620
# running case 621
# running case 622
# running case 623
# running case 624
# running case 625
# running case 626
# running case 627
# running case 628
# running case 629
# running case 630
# running case 631
# running case 632
# running case 633
# running case 634
# running case 635
# running case 636
# running case 637
# running case 638
# running case 639
# running case 640
# running case 641
# running case 642
# running case 643
# running case 644
# running case 645
# running case 646
# running case 647
# running case 648
# running case 649
# running case 650
# running case 651
# running case 652
# running case 653
# running case 654
# running case 655
# running case 656
# running case 657
# running case 658
# running case 659
# running case 660
# running case 661
# running case 662
# running case 663
# running case 664
# running case 665
# running case 666
# running case 667
# running case 668
# running case 669
# running case 670
# running case 671
# running case 672
# running case 673
# running case 674
# running case 675
# running case 676
# running case 677
# running case 678
# running case 679
# running case 680
# running case 681
# running case 682
# running case 683
# running case 684
# running case 685
# running case 686
# running case 687
# running case 688
# running case 689
# running case 690
# running case 691
# running case 692
# running case 693
# running case 694
# running case 695
# running case 696
# running case 697
# running case 698
# running case 699
# running case 700
# running case 701
# running case 702
# running case 703
# running case 704
# running case 705
# running case 706
# running case 707
# running case 708
# running case 709
# running case 710
# running case 711
# running case 712
# running case 713
# running case 714
# running case 715
# running case 716
# running case 717
# running case 718
# running case 719
# running case 720
# running case 721
# running case 722
# running case 723
# running case 724
# running case 725
# running case 726
# running case 727
# running case 728
# running case 729
# running case 730
# running case 731
# running case 732
# running case 733
# running case 734
# running case 735
# running case 736
# running case 737
# running case 738
# running case 739
# running case 740
# running case 741
# running case 742
# running case 743
# running case 744
# running case 745
# running case 746
# running case 747
# running case 748
# running case 749
# running case 750
# running case 751
# running case 752
# running case 753
# running case 754
# running case 755
# running case 756
# running case 757
# running case 758
# running case 759
# running case 760
# running case 761
# running case 762
# running case 763
# running case 764
# running case 765
# running case 766
# running case 767
# running case 768
# running case 769
# running case 770
# running case 771
# running case 772
# running case 773
# running case 774
# running case 775
# running case 776
# running case 777
# running case 778
# running case 779
# running case 780
# running case 781
# running case 782
# running case 783
# running case 784
# running case 785
# running case 786
# running case 787
# running case 788
# running case 789
# running case 790
# running case 791
# running case 792
# running case 793
# running case 794
# running case 795
# running case 796
# running case 797
# running case 798
# running case 799
# running case 800
# running case 801
# running case 802
# running case 803
# running case 804
# running case 805
# running case 806
# running case 807
# running case 808
# running case 809
# running case 810
# running case 811
# running case 812
# running case 813
# running case 814
# running case 815
# running case 816
# running case 817
# running case 818
# running case 819
# running case 820
# running case 821
# running case 822
# running case 823
# running case 824
# running case 825
# running case 826
# running case 827
# running case 828
# running case 829
# running case 830
# running case 831
# running case 832
# running case 833
# running case 834
# running case 835
# running case 836
# running case 837
# running case 838
# running case 839
# running case 840
# running case 841
# running case 842
# running case 843
# running case 844
# running case 845
# running case 846
# running case 847
# running case 848
# running case 849
# running case 850
# running case 851
# running case 852
# running case 853
# running case 854
# running case 855
# running case 856
# running case 857
# running case 858
# running case 859
# running case 860
# running case 861
# running case 862
# running case 863
# running case 864
# running case 865
# running case 866
# running case 867
# running case 868
# running case 869
# running case 870
# running case 871
# running case 872
# running case 873
# running case 874
# running case 875
# running case 876
# running case 877
# running case 878
# running case 879
# running case 880
# running case 881
# running case 882
# running case 883
# running case 884
# running case 885
# running case 886
# running case 887
# running case 888
# running case 889
# running case 890
# running case 891
# running case 892
# running case 893
# running case 894
# running case 895
# running case 896
# running case 897
# running case 898
# running case 899
# running case 900
# running case 901
# running case 902
# running case 903
# running case 904
# running case 905
# running case 906
# running case 907
# running case 908
# running case 909
# running case 910
# running case 911
# running case 912
# running case 913
# running case 914
# running case 915
# running case 916
# running case 917
# running case 918
# running case 919
# running case 920
# running case 921
# running case 922
# running case 923
# running case 924
# running case 925
# running case 926
# running case 927
# running case 928
# running case 929
# running case 930
# running case 931
# running case 932
# running case 933
# running case 934
# running case 935
# running case 936
# running case 937
# running case 938
# running case 939
# running case 940
# running case 941
# running case 942
# running case 943
# running case 944
# running case 945
# running case 946
# running case 947
# running case 948
# running case 949
# running case 950
# running case 951
# running case 952
# running case 953
# running case 954
# running case 955
# running case 956
# running case 957
# running case 958
# running case 959
# running case 960
# running case 961
# running case 962
# running case 963
# running case 964
# running case 965
# running case 966
# running case 967
# running case 968
# running case 969
# running case 970
# running case 971
# running case 972
# running case 973
# running case 974
# running case 975
# running case 976
# running case 977
# running case 978
# running case 979
# running case 980
# running case 981
# running case 982
# running case 983
# running case 984
# running case 985
# running case 986
# running case 987
# running case 988
# running case 989
# running case 990
# running case 991
# running case 992
# running case 993
# running case 994
# running case 995
# running case 996
# running case 997
# running case 998
# running case 999
# running case 1000
# running case 1001
# running case 1002
# running case 1003
# running case 1004
# running case 1005
# running case 1006
# running case 1007
# running case 1008
# running case 1009
# running case 1010
# running case 1011
# running case 1012
# running case 1013
# running case 1014
# running case 1015
# running case 1016
# running case 1017
# running case 1018
# running case 1019
# running case 1020
# running case 1021
# running case 1022
# running case 1023
# running case 1024
# running case 1025
# running case 1026
# running case 1027
# running case 1028
# running case 1029
# running case 1030
# running case 1031
# running case 1032
# running case 1033
# running case 1034
# running case 1035
# running case 1036
# running case 1037
# running case 1038
# running case 1039
# running case 1040
# running case 1041
# running case 1042
# running case 1043
# running case 1044
# running case 1045
# running case 1046
# running case 1047
# running case 1048
# running case 1049
# running case 1050
# running case 1051
# running case 1052
# running case 1053
# running case 1054
# running case 1055
# running case 1056
# running case 1057
# running case 1058
# running case 1059
# running case 1060
# running case 1061
# running case 1062
# running case 1063
# running case 1064
# running case 1065
# running case 1066
# running case 1067
# running case 1068
# running case 1069
# running case 1070
# running case 1071
# running case 1072
# running case 1073
# running case 1074
# running case 1075
# running case 1076
# running case 1077
# running case 1078
# running case 1079
# running case 1080
# running case 1081
# running case 1082
# running case 1083
# running case 1084
# running case 1085
# running case 1086
# running case 1087
# running case 1088
# running case 1089
# running case 1090
# running case 1091
# running case 1092
# running case 1093
# running case 1094
# running case 1095
# running case 1096
# running case 1097
# running case 1098
# running case 1099
# running case 1100
# running case 1101
# running case 1102
# running case 1103
# running case 1104
# running case 1105
# running case 1106
# running case 1107
# running case 1108
# running case 1109
# running case 1110
# running case 1111
# running case 1112
# running case 1113
# running case 1114
# running case 1115
# running case 1116
# running case 1117
# running case 1118
# running case 1119
# running case 1120
# running case 1121
# running case 1122
# running case 1123
# running case 1124
# running case 1125
# running case 1126
# running case 1127
# running case 1128
# running case 1129
# running case 1130
# running case 1131
# running case 1132
# running case 1133
# running case 1134
# running case 1135
# running case 1136
# running case 1137
# running case 1138
# running case 1139
# running case 1140
# running case 1141
# running case 1142
# running case 1143
# running case 1144
# running case 1145
# running case 1146
# running case 1147
# running case 1148
# running case 1149
# running case 1150
# running case 1151
# running case 1152
# running case 1153
# running case 1154
# running case 1155
# running case 1156
# running case 1157
# running case 1158
# running case 1159
# running case 1160
# running case 1161
# running case 1162
# running case 1163
# running case 1164
# running case 1165
# running case 1166
# running case 1167
# running case 1168
# running case 1169
# running case 1170
# running case 1171
# running case 1172
# running case 1173
# running case 1174
# running case 1175
# running case 1176
# running case 1177
# running case 1178
# running case 1179
# running case 1180
# running case 1181
# running case 1182
# running case 1183
# running case 1184
# running case 1185
# running case 1186
# running case 1187
# running case 1188
# running case 1189
# running case 1190
# running case 1191
# running case 1192
# running case 1193
# running case 1194
# running case 1195
# running case 1196
# running case 1197
# running case 1198
# running case 1199
# running case 1200
# running case 1201
# running case 1202
# running case 1203
# running case 1204
# running case 1205
# running case 1206
# running case 1207
# running case 1208
# running case 1209
# running case 1210
# running case 1211
# running case 1212
# running case 1213
# running case 1214
# running case 1215
# running case 1216
# running case 1217
# running case 1218
# running case 1219
# running case 1220
# running case 1221
# running case 1222
# running case 1223
# running case 1224
# running case 1225
# running case 1226
# running case 1227
# running case 1228
# running case 1229
# running case 1230
# running case 1231
# running case 1232
# running case 1233
# running case 1234
# running case 1235
# running case 1236
# running case 1237
# running case 1238
# running case 1239
# running case 1240
# running case 1241
# running case 1242
# running case 1243
# running case 1244
# running case 1245
# running case 1246
# running case 1247
# running case 1248
# running case 1249
# running case 1250
# running case 1251
# running case 1252
# running case 1253
# running case 1254
# running case 1255
# running case 1256
# running case 1257
# running case 1258
# running case 1259
# running case 1260
# running case 1261
# running case 1262
# running case 1263
# running case 1264
# running case 1265
# running case 1266
# running case 1267
# running case 1268
# running case 1269
# running case 1270
# running case 1271
# running case 1272
# running case 1273
# running case 1274
# running case 1275
# running case 1276
# running case 1277
# running case 1278
# running case 1279
# running case 1280
# running case 1281
# running case 1282
# running case 1283
# running case 1284
# running case 1285
# running case 1286
# running case 1287
# running case 1288
# running case 1289
# running case 1290
# running case 1291
# running case 1292
# running case 1293
# running case 1294
# running case 1295
# running case 1296
# running case 1297
# running case 1298
# running case 1299
# running case 1300
# running case 1301
# running case 1302
# running case 1303
# running case 1304
# running case 1305
# running case 1306
# running case 1307
# running case 1308
# running case 1309
# running case 1310
# running case 1311
# running case 1312
# running case 1313
# running case 1314
# running case 1315
# running case 1316
# running case 1317
# running case 1318
# running case 1319
# running case 1320
# running case 1321
# running case 1322
# running case 1323
# running case 1324
# running case 1325
# running case 1326
# running case 1327
# running case 1328
# running case 1329
# running case 1330
# running case 1331
# running case 1332
# running case 1333
# running case 1334
# running case 1335
# running case 1336
# running case 1337
# running case 1338
# running case 1339
# running case 1340
# running case 1341
# running case 1342
# running case 1343
# running case 1344
# running case 1345
# running case 1346
# running case 1347
# running case 1348
# running case 1349
# running case 1350
# running case 1351
# running case 1352
# running case 1353
# running case 1354
# running case 1355
# running case 1356
# running case 1357
# running case 1358
# running case 1359
# running case 1360
# running case 1361
# running case 1362
# running case 1363
# running case 1364
# running case 1365
# running case 1366
# running case 1367
# running case 1368
# running case 1369
# running case 1370
# running case 1371
# running case 1372
# running case 1373
# running case 1374
# running case 1375
# running case 1376
# running case 1377
# running case 1378
# running case 1379
# running case 1380
# running case 1381
# running case 1382
# running case 1383
# running case 1384
# running case 1385
# running case 1386
# running case 1387
# running case 1388
# running case 1389
# running case 1390
# running case 1391
# running case 1392
# running case 1393
# running case 1394
# running case 1395
# running case 1396
# running case 1397
# running case 1398
# running case 1399
# running case 1400
# running case 1401
# running case 1402
# running case 1403
# running case 1404
# running case 1405
# running case 1406
# running case 1407
# running case 1408
# running case 1409
# running case 1410
# running case 1411
# running case 1412
# running case 1413
# running case 1414
# running case 1415
# running case 1416
# running case 1417
# running case 1418
# running case 1419
# running case 1420
# running case 1421
# running case 1422
# running case 1423
# running case 1424
# running case 1425
# running case 1426
# running case 1427
# running case 1428
# running case 1429
# running case 1430
# running case 1431
# running case 1432
# running case 1433
# running case 1434
# running case 1435
# running case 1436
# running case 1437
# running case 1438
# running case 1439
# running case 1440
# running case 1441
# running case 1442
# running case 1443
# running case 1444
# running case 1445
# running case 1446
# running case 1447
# running case 1448
# running case 1449
# running case 1450
# running case 1451
# running case 1452
# running case 1453
# running case 1454
# running case 1455
# running case 1456
# running case 1457
# running case 1458
# running case 1459
# running case 1460
# running case 1461
# running case 1462
# running case 1463
# running case 1464
# running case 1465
# running case 1466
# running case 1467
# running case 1468
# running case 1469
# running case 1470
# running case 1471
# running case 1472
# running case 1473
# running case 1474
# running case 1475
# running case 1476
# running case 1477
# running case 1478
# running case 1479
# running case 1480
# running case 1481
# running case 1482
# running case 1483
# running case 1484
# running case 1485
# running case 1486
# running case 1487
# running case 1488
# running case 1489
# running case 1490
# running case 1491
# running case 1492
# running case 1493
# running case 1494
# running case 1495
# running case 1496
# running case 1497
# running case 1498
# running case 1499
# running case 1500
# running case 1501
# running case 1502
# running case 1503
# running case 1504
# running case 1505
# running case 1506
# running case 1507
# running case 1508
# running case 1509
# running case 1510
# running case 1511
# running case 1512
# running case 1513
# running case 1514
# running case 1515
# running case 1516
# running case 1517
# running case 1518
# running case 1519
# running case 1520
# running case 1521
# running case 1522
# running case 1523
# running case 1524
# running case 1525
# running case 1526
# running case 1527
# running case 1528
# running case 1529
# running case 1530
# running case 1531
# running case 1532
# running case 1533
# running case 1534
# running case 1535
# running case 1536
# running case 1537
# running case 1538
# running case 1539
# running case 1540
# running case 1541
# running case 1542
# running case 1543
# running case 1544
# running case 1545
# running case 1546
# running case 1547
# running case 1548
# running case 1549
# running case 1550
# running case 1551
# running case 1552
# running case 1553
# running case 1554
# running case 1555
# running case 1556
# running case 1557
# running case 1558
# running case 1559
# running case 1560
# running case 1561
# running case 1562
# running case 1563
# running case 1564
# running case 1565
# running case 1566
# running case 1567
# running case 1568
# running case 1569
# running case 1570
# running case 1571
# running case 1572
# running case 1573
# running case 1574
# running case 1575
# running case 1576
# running case 1577
# running case 1578
# running case 1579
# running case 1580
# running case 1581
# running case 1582
# running case 1583
# running case 1584
# running case 1585
# running case 1586
# running case 1587
# running case 1588
# running case 1589
# running case 1590
# running case 1591
# running case 1592
# running case 1593
# running case 1594
# running case 1595
# running case 1596
# running case 1597
# running case 1598
# running case 1599
# running case 1600
# running case 1601
# running case 1602
# running case 1603
# running case 1604
# running case 1605
# running case 1606
# running case 1607
# running case 1608
# running case 1609
# running case 1610
# running case 1611
# running case 1612
# running case 1613
# running case 1614
# running case 1615
# running case 1616
# running case 1617
# running case 1618
# running case 1619
# running case 1620
# running case 1621
# running case 1622
# running case 1623
# running case 1624
# running case 1625
# running case 1626
# running case 1627
# running case 1628
# running case 1629
# running case 1630
# running case 1631
# running case 1632
# running case 1633
# running case 1634
# running case 1635
# running case 1636
# running case 1637
# running case 1638
# running case 1639
# running case 1640
# running case 1641
# running case 1642
# running case 1643
# running case 1644
# running case 1645
# running case 1646
# running case 1647
# running case 1648
# running case 1649
# running case 1650
# running case 1651
# running case 1652
# running case 1653
# running case 1654
# running case 1655
# running case 1656
# running case 1657
# running case 1658
# running case 1659
# running case 1660
# running case 1661
# running case 1662
# running case 1663
# running case 1664
# running case 1665
# running case 1666
# running case 1667
# running case 1668
# running case 1669
# running case 1670
# running case 1671
# running case 1672
# running case 1673
# running case 1674
# running case 1675
# running case 1676
# running case 1677
# running case 1678
# running case 1679
# running case 1680
# running case 1681
# running case 1682
# running case 1683
# running case 1684
# running case 1685
# running case 1686
# running case 1687
# running case 1688
# running case 1689
# running case 1690
# running case 1691
# running case 1692
# running case 1693
# running case 1694
# running case 1695
# running case 1696
# running case 1697
# running case 1698
# running case 1699
# running case 1700
# running case 1701
# running case 1702
# running case 1703
# running case 1704
# running case 1705
# running case 1706
# running case 1707
# running case 1708
# running case 1709
# running case 1710
# running case 1711
# running case 1712
# running case 1713
# running case 1714
# running case 1715
# running case 1716
# running case 1717
# running case 1718
# running case 1719
# running case 1720
# running case 1721
# running case 1722
# running case 1723
# running case 1724
# running case 1725
# running case 1726
# running case 1727
# running case 1728
# running case 1729
# running case 1730
# running case 1731
# running case 1732
# running case 1733
# running case 1734
# running case 1735
# running case 1736
# running case 1737
# running case 1738
# running case 1739
# running case 1740
# running case 1741
# running case 1742
# running case 1743
# running case 1744
# running case 1745
# running case 1746
# running case 1747
# running case 1748
# running case 1749
# running case 1750
# running case 1751
# running case 1752
# running case 1753
# running case 1754
# running case 1755
# running case 1756
# running case 1757
# running case 1758
# running case 1759
# running case 1760
# running case 1761
# running case 1762
# running case 1763
# running case 1764
# running case 1765
# running case 1766
# running case 1767
# running case 1768
# running case 1769
# running case 1770
# running case 1771
# running case 1772
# running case 1773
# running case 1774
# running case 1775
# running case 1776
# running case 1777
# running case 1778
# running case 1779
# running case 1780
# running case 1781
# running case 1782
# running case 1783
# running case 1784
# running case 1785
# running case 1786
# running case 1787
# running case 1788
# running case 1789
# running case 1790
# running case 1791
# running case 1792
# running case 1793
# running case 1794
# running case 1795
# running case 1796
# running case 1797
# running case 1798
# running case 1799
# running case 1800
# running case 1801
# running case 1802
# running case 1803
# running case 1804
# running case 1805
# running case 1806
# running case 1807
# running case 1808
# running case 1809
# running case 1810
# running case 1811
# running case 1812
# running case 1813
# running case 1814
# running case 1815
# running case 1816
# running case 1817
# running case 1818
# running case 1819
# running case 1820
# running case 1821
# running case 1822
# running case 1823
# running case 1824
# running case 1825
# running case 1826
# running case 1827
# running case 1828
# running case 1829
# running case 1830
# running case 1831
# running case 1832
# running case 1833
# running case 1834
# running case 1835
# running case 1836
# running case 1837
# running case 1838
# running case 1839
# running case 1840
# running case 1841
# running case 1842
# running case 1843
# running case 1844
# running case 1845
# running case 1846
# running case 1847
# running case 1848
# running case 1849
# running case 1850
# running case 1851
# running case 1852
# running case 1853
# running case 1854
# running case 1855
# running case 1856
# running case 1857
# running case 1858
# running case 1859
# running case 1860
# running case 1861
# running case 1862
# running case 1863
# running case 1864
# running case 1865
# running case 1866
# running case 1867
# running case 1868
# running case 1869
# running case 1870
# running case 1871
# running case 1872
# running case 1873
# running case 1874
# running case 1875
# running case 1876
# running case 1877
# running case 1878
# running case 1879
# running case 1880
# running case 1881
# running case 1882
# running case 1883
# running case 1884
# running case 1885
# running case 1886
# running case 1887
# running case 1888
# running case 1889
# running case 1890
# running case 1891
# running case 1892
# running case 1893
# running case 1894
# running case 1895
# running case 1896
# running case 1897
# running case 1898
# running case 1899
# running case 1900
# running case 1901
# running case 1902
# running case 1903
# running case 1904
# running case 1905
# running case 1906
# running case 1907
# running case 1908
# running case 1909
# running case 1910
# running case 1911
# running case 1912
# running case 1913
# running case 1914
# running case 1915
# running case 1916
# running case 1917
# running case 1918
# running case 1919
# running case 1920
# running case 1921
# running case 1922
# running case 1923
# running case 1924
# running case 1925
# running case 1926
# running case 1927
# running case 1928
# running case 1929
# running case 1930
# running case 1931
# running case 1932
# running case 1933
# running case 1934
# running case 1935
# running case 1936
# running case 1937
# running case 1938
# running case 1939
# running case 1940
# running case 1941
# running case 1942
# running case 1943
# running case 1944
# running case 1945
# running case 1946
# running case 1947
# running case 1948
# running case 1949
# running case 1950
# running case 1951
# running case 1952
# running case 1953
# running case 1954
# running case 1955
# running case 1956
# running case 1957
# running case 1958
# running case 1959
# running case 1960
# running case 1961
# running case 1962
# running case 1963
# running case 1964
# running case 1965
# running case 1966
# running case 1967
# running case 1968
# running case 1969
# running case 1970
# running case 1971
# running case 1972
# running case 1973
# running case 1974
# running case 1975
# running case 1976
# running case 1977
# running case 1978
# running case 1979
# running case 1980
# running case 1981
# running case 1982
# running case 1983
# running case 1984
# running case 1985
# running case 1986
# running case 1987
# running case 1988
# running case 1989
# running case 1990
# running case 1991
# running case 1992
# running case 1993
# running case 1994
# running case 1995
# running case 1996
# running case 1997
# running case 1998
# running case 1999
# running case 2000
# running case 2001
# running case 2002
# running case 2003
# running case 2004
# running case 2005
# running case 2006
# running case 2007
# running case 2008
# running case 2009
# running case 2010
# running case 2011
# running case 2012
# running case 2013
# running case 2014
# running case 2015
# running case 2016
# running case 2017
# running case 2018
# running case 2019
# running case 2020
# running case 2021
# running case 2022
# running case 2023
# running case 2024
# running case 2025
# running case 2026
# running case 2027
# running case 2028
# running case 2029
# running case 2030
# running case 2031
# running case 2032
# running case 2033
# running case 2034
# running case 2035
# running case 2036
# running case 2037
# running case 2038
# running case 2039
# running case 2040
# running case 2041
# running case 2042
# running case 2043
# running case 2044
# running case 2045
# running case 2046
# running case 2047
# running case 2048
# running case 2049
# running case 2050
# running case 2051
# running case 2052
# running case 2053
# running case 2054
# running case 2055
# running case 2056
# running case 2057
# running case 2058
# running case 2059
# running case 2060
# running case 2061
# running case 2062
# running case 2063
# running case 2064
# running case 2065
# running case 2066
# running case 2067
# running case 2068
# running case 2069
# running case 2070
# running case 2071
# running case 2072
# running case 2073
# running case 2074
# running case 2075
# running case 2076
# running case 2077
# running case 2078
# running case 2079
# running case 2080
# running case 2081
# running case 2082
# running case 2083
# running case 2084
# running case 2085
# running case 2086
# running case 2087
# running case 2088
# running case 2089
# running case 2090
# running case 2091
# running case 2092
# running case 2093
# running case 2094
# running case 2095
# running case 2096
# running case 2097
# running case 2098
# running case 2099
# running case 2100
# running case 2101
# running case 2102
# running case 2103
# running case 2104
# running case 2105
# running case 2106
# running case 2107
# running case 2108
# running case 2109
# running case 2110
# running case 2111
# running case 2112
# running case 2113
# running case 2114
# running case 2115
# running case 2116
# running case 2117
# running case 2118
# running case 2119
# running case 2120
# running case 2121
# running case 2122
# running case 2123
# running case 2124
# running case 2125
# running case 2126
# running case 2127
# running case 2128
# running case 2129
# running case 2130
# running case 2131
# running case 2132
# running case 2133
# running case 2134
# running case 2135
# running case 2136
# running case 2137
# running case 2138
# running case 2139
# running case 2140
# running case 2141
# running case 2142
# running case 2143
# running case 2144
# running case 2145
# running case 2146
# running case 2147
# running case 2148
# running case 2149
# running case 2150
# running case 2151
# running case 2152
# running case 2153
# running case 2154
# running case 2155
# running case 2156
# running case 2157
# running case 2158
# running case 2159
# running case 2160
# running case 2161
# running case 2162
# running case 2163
# running case 2164
# running case 2165
# running case 2166
# running case 2167
# running case 2168
# running case 2169
# running case 2170
# running case 2171
# running case 2172
# running case 2173
# running case 2174
# running case 2175
# running case 2176
# running case 2177
# running case 2178
# running case 2179
# running case 2180
# running case 2181
# running case 2182
# running case 2183
# running case 2184
# running case 2185
# running case 2186
# running case 2187
# running case 2188
# running case 2189
# running case 2190
# running case 2191
# running case 2192
# running case 2193
# running case 2194
# running case 2195
# running case 2196
# running case 2197
# running case 2198
# running case 2199
# running case 2200
# running case 2201
# running case 2202
# running case 2203
# running case 2204
# running case 2205
# running case 2206
# running case 2207
# running case 2208
# running case 2209
# running case 2210
# running case 2211
# running case 2212
# running case 2213
# running case 2214
# running case 2215
# running case 2216
# running case 2217
# running case 2218
# running case 2219
# running case 2220
# running case 2221
# running case 2222
# running case 2223
# running case 2224
# running case 2225
# running case 2226
# running case 2227
# running case 2228
# running case 2229
# running case 2230
# running case 2231
# running case 2232
# running case 2233
# running case 2234
# running case 2235
# running case 2236
# running case 2237
# running case 2238
# running case 2239
# running case 2240
# running case 2241
# running case 2242
# running case 2243
# running case 2244
# running case 2245
# running case 2246
# running case 2247
# running case 2248
# running case 2249
# running case 2250
# running case 2251
# running case 2252
# running case 2253
# running case 2254
# running case 2255
# running case 2256
# running case 2257
# running case 2258
# running case 2259
# running case 2260
# running case 2261
# running case 2262
# running case 2263
# running case 2264
# running case 2265
# running case 2266
# running case 2267
# running case 2268
# running case 2269
# running case 2270
# running case 2271
# running case 2272
# running case 2273
# running case 2274
# running case 2275
# running case 2276
# running case 2277
# running case 2278
# running case 2279
# running case 2280
# running case 2281
# running case 2282
# running case 2283
# running case 2284
# running case 2285
# running case 2286
# running case 2287
# running case 2288
# running case 2289
# running case 2290
# running case 2291
# running case 2292
# running case 2293
# running case 2294
# running case 2295
# running case 2296
# running case 2297
# running case 2298
# running case 2299
# running case 2300
# running case 2301
# running case 2302
# running case 2303
# running case 2304
# running case 2305
# running case 2306
# running case 2307
# running case 2308
# running case 2309
# running case 2310
# running case 2311
# running case 2312
# running case 2313
# running case 2314
# running case 2315
# running case 2316
# running case 2317
# running case 2318
# running case 2319
# running case 2320
# running case 2321
# running case 2322
# running case 2323
# running case 2324
# running case 2325
# running case 2326
# running case 2327
# running case 2328
# running case 2329
# running case 2330
# running case 2331
# running case 2332
# running case 2333
# running case 2334
# running case 2335
# running case 2336
# running case 2337
# running case 2338
# running case 2339
# running case 2340
# running case 2341
# running case 2342
# running case 2343
# running case 2344
# running case 2345
# running case 2346
# running case 2347
# running case 2348
# running case 2349
# running case 2350
# running case 2351
# running case 2352
# running case 2353
# running case 2354
# running case 2355
# running case 2356
# running case 2357
# running case 2358
# running case 2359
# running case 2360
# running case 2361
# running case 2362
# running case 2363
# running case 2364
# running case 2365
# running case 2366
# running case 2367
# running case 2368
# running case 2369
# running case 2370
# running case 2371
# running case 2372
# running case 2373
# running case 2374
# running case 2375
# running case 2376
# running case 2377
# running case 2378
# running case 2379
# running case 2380
# running case 2381
# running case 2382
# running case 2383
# running case 2384
# running case 2385
# running case 2386
# running case 2387
# running case 2388
# running case 2389
# running case 2390
# running case 2391
# running case 2392
# running case 2393
# running case 2394
# running case 2395
# running case 2396
# running case 2397
# running case 2398
# running case 2399
# running case 2400
# running case 2401
# running case 2402
# running case 2403
# running case 2404
# running case 2405
# running case 2406
# running case 2407
# running case 2408
# running case 2409
# running case 2410
# running case 2411
# running case 2412
# running case 2413
# running case 2414
# running case 2415
# running case 2416
# running case 2417
# running case 2418
# running case 2419
# running case 2420
# running case 2421
# running case 2422
# running case 2423
# running case 2424
# running case 2425
# running case 2426
# running case 2427
# running case 2428
# running case 2429
# running case 2430
# running case 2431
# running case 2432
# running case 2433
# running case 2434
# running case 2435
# running case 2436
# running case 2437
# running case 2438
# running case 2439
# running case 2440
# running case 2441
# running case 2442
# running case 2443
# running case 2444
# running case 2445
# running case 2446
# running case 2447
# running case 2448
# running case 2449
# running case 2450
# running case 2451
# running case 2452
# running case 2453
# running case 2454
# running case 2455
# running case 2456
# running case 2457
# running case 2458
# running case 2459
# running case 2460
# running case 2461
# running case 2462
# running case 2463
# running case 2464
# running case 2465
# running case 2466
# running case 2467
# running case 2468
# running case 2469
# running case 2470
# running case 2471
# running case 2472
# running case 2473
# running case 2474
# running case 2475
# running case 2476
# running case 2477
# running case 2478
# running case 2479
# running case 2480
# running case 2481
# running case 2482
# running case 2483
# running case 2484
# running case 2485
# running case 2486
# running case 2487
# running case 2488
# running case 2489
# running case 2490
# running case 2491
# running case 2492
# running case 2493
# running case 2494
# running case 2495
# running case 2496
# running case 2497
# running case 2498
# running case 2499
# running case 2500
# running case 2501
# running case 2502
# running case 2503
# running case 2504
# running case 2505
# running case 2506
# running case 2507
# running case 2508
# running case 2509
# running case 2510
# running case 2511
# running case 2512
# running case 2513
# running case 2514
# running case 2515
# running case 2516
# running case 2517
# running case 2518
# running case 2519
# running case 2520
# running case 2521
# running case 2522
# running case 2523
# running case 2524
# running case 2525
# running case 2526
# running case 2527
# running case 2528
# running case 2529
# running case 2530
# running case 2531
# running case 2532
# running case 2533
# running case 2534
# running case 2535
# running case 2536
# running case 2537
# running case 2538
# running case 2539
# running case 2540
# running case 2541
# running case 2542
# running case 2543
# running case 2544
# running case 2545
# running case 2546
# running case 2547
# running case 2548
# running case 2549
# running case 2550
# running case 2551
# running case 2552
# running case 2553
# running case 2554
# running case 2555
# running case 2556
# running case 2557
# running case 2558
# running case 2559
# running case 2560
# running case 2561
# running case 2562
# running case 2563
# running case 2564
# running case 2565
# running case 2566
# running case 2567
# running case 2568
# running case 2569
# running case 2570
# running case 2571
# running case 2572
# running case 2573
# running case 2574
# running case 2575
# running case 2576
# running case 2577
# running case 2578
# running case 2579
# running case 2580
# running case 2581
# running case 2582
# running case 2583
# running case 2584
# running case 2585
# running case 2586
# running case 2587
# running case 2588
# running case 2589
# running case 2590
# running case 2591
# running case 2592
# running case 2593
# running case 2594
# running case 2595
# running case 2596
# running case 2597
# running case 2598
# running case 2599
# running case 2600
# running case 2601
# running case 2602
# running case 2603
# running case 2604
# running case 2605
# running case 2606
# running case 2607
# running case 2608
# running case 2609
# running case 2610
# running case 2611
# running case 2612
# running case 2613
# running case 2614
# running case 2615
# running case 2616
# running case 2617
# running case 2618
# running case 2619
# running case 2620
# running case 2621
# running case 2622
# running case 2623
# running case 2624
# running case 2625
# running case 2626
# running case 2627
# running case 2628
# running case 2629
# running case 2630
# running case 2631
# running case 2632
# running case 2633
# running case 2634
# running case 2635
# running case 2636
# running case 2637
# running case 2638
# running case 2639
# running case 2640
# running case 2641
# running case 2642
# running case 2643
# running case 2644
# running case 2645
# running case 2646
# running case 2647
# running case 2648
# running case 2649
# running case 2650
# running case 2651
# running case 2652
# running case 2653
# running case 2654
# running case 2655
# running case 2656
# running case 2657
# running case 2658
# running case 2659
# running case 2660
# running case 2661
# running case 2662
# running case 2663
# running case 2664
# running case 2665
# running case 2666
# running case 2667
# running case 2668
# running case 2669
# running case 2670
# running case 2671
# running case 2672
# running case 2673
# running case 2674
# running case 2675
# running case 2676
# running case 2677
# running case 2678
# running case 2679
# running case 2680
# running case 2681
# running case 2682
# running case 2683
# running case 2684
# running case 2685
# running case 2686
# running case 2687
# running case 2688
# running case 2689
# running case 2690
# running case 2691
# running case 2692
# running case 2693
# running case 2694
# running case 2695
# running case 2696
# running case 2697
# running case 2698
# running case 2699
# running case 2700
# running case 2701
# running case 2702
# running case 2703
# running case 2704
# running case 2705
# running case 2706
# running case 2707
# running case 2708
# running case 2709
# running case 2710
# running case 2711
# running case 2712
# running case 2713
# running case 2714
# running case 2715
# running case 2716
# running case 2717
# running case 2718
# running case 2719
# running case 2720
# running case 2721
# running case 2722
# running case 2723
# running case 2724
# running case 2725
# running case 2726
# running case 2727
# running case 2728
# running case 2729
# running case 2730
# running case 2731
# running case 2732
# running case 2733
# running case 2734
# running case 2735
# running case 2736
# running case 2737
# running case 2738
# running case 2739
# running case 2740
# running case 2741
# running case 2742
# running case 2743
# running case 2744
# running case 2745
# running case 2746
# running case 2747
# running case 2748
# running case 2749
# running case 2750
# running case 2751
# running case 2752
# running case 2753
# running case 2754
# running case 2755
# running case 2756
# running case 2757
# running case 2758
# running case 2759
# running case 2760
# running case 2761
# running case 2762
# running case 2763
# running case 2764
# running case 2765
# running case 2766
# running case 2767
# running case 2768
# running case 2769
# running case 2770
# running case 2771
# running case 2772
# running case 2773
# running case 2774
# running case 2775
# running case 2776
# running case 2777
# running case 2778
# running case 2779
# running case 2780
# running case 2781
# running case 2782
# running case 2783
# running case 2784
# running case 2785
# running case 2786
# running case 2787
# running case 2788
# running case 2789
# running case 2790
# running case 2791
# running case 2792
# running case 2793
# running case 2794
# running case 2795
# running case 2796
# running case 2797
# running case 2798
# running case 2799
# running case 2800
# running case 2801
# running case 2802
# running case 2803
# running case 2804
# running case 2805
# running case 2806
# running case 2807
# running case 2808
# running case 2809
# running case 2810
# running case 2811
# running case 2812
# running case 2813
# running case 2814
# running case 2815
# running case 2816
# running case 2817
# running case 2818
# running case 2819
# running case 2820
# running case 2821
# running case 2822
# running case 2823
# running case 2824
# running case 2825
# running case 2826
# running case 2827
# running case 2828
# running case 2829
# running case 2830
# running case 2831
# running case 2832
# running case 2833
# running case 2834
# running case 2835
# running case 2836
# running case 2837
# running case 2838
# running case 2839
# running case 2840
# running case 2841
# running case 2842
# running case 2843
# running case 2844
# running case 2845
# running case 2846
# running case 2847
# running case 2848
# running case 2849
# running case 2850
# running case 2851
# running case 2852
# running case 2853
# running case 2854
# running case 2855
# running case 2856
# running case 2857
# running case 2858
# running case 2859
# running case 2860
# running case 2861
# running case 2862
# running case 2863
# running case 2864
# running case 2865
# running case 2866
# running case 2867
# running case 2868
# running case 2869
# running case 2870
# running case 2871
# running case 2872
# running case 2873
# running case 2874
# running case 2875
# running case 2876
# running case 2877
# running case 2878
# running case 2879
# running case 2880
# running case 2881
# running case 2882
# running case 2883
# running case 2884
# running case 2885
# running case 2886
# running case 2887
# running case 2888
# running case 2889
# running case 2890
# running case 2891
# running case 2892
# running case 2893
# running case 2894
# running case 2895
# running case 2896
# running case 2897
# running case 2898
# running case 2899
# running case 2900
# running case 2901
# running case 2902
# running case 2903
# running case 2904
# running case 2905
# running case 2906
# running case 2907
# running case 2908
# running case 2909
# running case 2910
# running case 2911
# running case 2912
# running case 2913
# running case 2914
# running case 2915
# running case 2916
# running case 2917
# running case 2918
# running case 2919
# running case 2920
# running case 2921
# running case 2922
# running case 2923
# running case 2924
# running case 2925
# running case 2926
# running case 2927
# running case 2928
# running case 2929
# running case 2930
# running case 2931
# running case 2932
# running case 2933
# running case 2934
# running case 2935
# running case 2936
# running case 2937
# running case 2938
# running case 2939
# running case 2940
# running case 2941
# running case 2942
# running case 2943
# running case 2944
# running case 2945
# running case 2946
# running case 2947
# running case 2948
# running case 2949
# running case 2950
# running case 2951
# running case 2952
# running case 2953
# running case 2954
# running case 2955
# running case 2956
# running case 2957
# running case 2958
# running case 2959
# running case 2960
# running case 2961
# running case 2962
# running case 2963
# running case 2964
# running case 2965
# running case 2966
# running case 2967
# running case 2968
# running case 2969
# running case 2970
# running case 2971
# running case 2972
# running case 2973
# running case 2974
# running case 2975
# running case 2976
# running case 2977
# running case 2978
# running case 2979
# running case 2980
# running case 2981
# running case 2982
# running case 2983
# running case 2984
# running case 2985
# running case 2986
# running case 2987
# running case 2988
# running case 2989
# running case 2990
# running case 2991
# running case 2992
# running case 2993
# running case 2994
# running case 2995
# running case 2996
# running case 2997
# running case 2998
# running case 2999
# running time was 2125.8444545269012
# [[0.000e+00 1.600e+01 3.300e+01 ... 0.000e+00 0.000e+00 1.000e+00]
#  [1.000e+00 5.200e+01 1.200e+01 ... 1.000e+00 1.000e+00 1.000e+00]
#  [2.000e+00 3.900e+01 4.000e+01 ... 0.000e+00 0.000e+00 1.000e+00]
#  ...
#  [2.997e+03 2.700e+01 4.400e+01 ... 0.000e+00 0.000e+00 1.000e+00]
#  [2.998e+03 7.000e+01 1.000e+01 ... 1.000e+00 0.000e+00 1.000e+00]
#  [2.999e+03 4.200e+01 1.800e+01 ... 1.000e+00 0.000e+00 1.000e+00]]

# %%
all_scores0=np.loadtxt("level9_level0_500_0.txt")
all_scores1=np.loadtxt("level9_level0_1500_0.txt")
all_scores2=np.loadtxt("level9_level0_3000_0.txt")
all_scores=np.zeros((7,5000))
all_scores[:,0:500]=all_scores0
all_scores[:,500:2000]=all_scores1
all_scores[:,2000:5000]=all_scores2
deltalevel9=0
deltalevel0=0
for i in range(all_scores.shape[1]):
    if all_scores[1,i]<all_scores[2,i]:
        #to calculate by how much a  human wins in average 
        deltalevel9+=(all_scores[2,i]-all_scores[1,i])
    else:
        deltalevel0+=(all_scores[1,i]-all_scores[2,i])
print("level 9 gainst level 0")
print(f"level 9 lost {(all_scores.shape[1]-int(all_scores.shape[1]-sum(all_scores[4])))} times of {all_scores.shape[1]} rounds")
print(f"the level 9 average is {round(np.mean(all_scores[1]),3)} points")
print(f"the level 0 average is {round(np.mean(all_scores[2]),3)} points")
print(f"the level 9 average adventage is  {round(np.mean(all_scores[2]-all_scores[1]),3)} points")
print(f"level 9 wins to {round(np.mean(100-all_scores[4]*100),1)} %")
print(f"level 9 average adventage {round(deltalevel9/(all_scores.shape[1]-sum(all_scores[4])),3)} points")
print(f"level 0 average adventage {round(deltalevel0/(sum(all_scores[4])),3)} points")

all_scores0=np.loadtxt("level11_level0_500_0.txt")
all_scores1=np.loadtxt("level11_level0_1500_0.txt")
all_scores2=np.loadtxt("level11_level0_3000_0.txt")
all_scores=np.zeros((7,5000))
all_scores[:,0:500]=all_scores0
all_scores[:,500:2000]=all_scores1
all_scores[:,2000:5000]=all_scores2
deltalevel9=0
deltalevel0=0
for i in range(all_scores.shape[1]):
    if all_scores[1,i]<all_scores[2,i]:
        #to calculate by how much a  human wins in average 
        deltalevel9+=(all_scores[2,i]-all_scores[1,i])
    else:
        deltalevel0+=(all_scores[1,i]-all_scores[2,i])
print(" ")
print("level 11 gainst level 0")
print(f"level 11 lost {all_scores.shape[1]-int(all_scores.shape[1]-sum(all_scores[4]))} times of {all_scores.shape[1]} rounds")
print(f"the level 11 average is {round(np.mean(all_scores[1]),3)} points")
print(f"the level 0 average is {round(np.mean(all_scores[2]),3)} points")
print(f"the level 11 average adventage is  {round(np.mean(all_scores[2]-all_scores[1]),3)} points")
print(f"level 11 wins to {round(np.mean(100-all_scores[4]*100),1)} %")
print(f"level 11 average adventage {round(deltalevel9/(all_scores.shape[1]-sum(all_scores[4])),3)} is points")
print(f"level 0 average adventage {round(deltalevel0/(sum(all_scores[4])),3)} is points")
# Out:
# level 9 gainst level 0
# level 9 lost 106 times of 5000 rounds
# the level 9 average is 27.766 points
# the level 0 average is 86.321 points
# the level 9 average adventage is  58.556 points
# level 9 wins to 97.9 %
# level 9 average adventage 60.379 points
# level 0 average adventage 25.613 points
#
# level 11 gainst level 0
# level 11 lost 43 times of 5000 rounds
# the level 11 average is 20.82 points
# the level 0 average is 85.997 points
# the level 11 average adventage is  65.177 points
# level 11 wins to 99.1 %
# level 11 average adventage 65.998 is points
# level 0 average adventage 29.465 is points

# %% [markdown]
# Level 9 and level 11 performs very well against level 0. That is ensuring and was not guranteed since it was trained mostly on rather few human data sets.
#
# Level 11 performs better with less than half the losses of level 9 as it should be since it is trained on winning in on imitating humans.

# %%
all_scores_a=np.loadtxt("level9_level6_500_0.txt")
all_scores_b=np.loadtxt("level9_level6_1500_0.txt")
all_scores_c=np.loadtxt("level9_level6_3000_0.txt")
all_scores=np.zeros((7,5000))
all_scores[:,0:500]=all_scores_a
all_scores[:,500:2000]=all_scores_b
all_scores[:,2000:5000]=all_scores_c
deltalevel9=0
deltalevel6=0
for i in range(all_scores.shape[1]):
    if all_scores[1,i]<all_scores[2,i]:
        #to calculate by how much a  human wins in average 
        deltalevel9+=(all_scores[2,i]-all_scores[1,i])
    else:
        deltalevel6+=(all_scores[1,i]-all_scores[2,i])
print("level 9 against level 6")
print(f"to {np.round(np.mean(all_scores[6])*100,3)} % finishes level 6")
print(f"level 9 won {int(all_scores.shape[1]-sum(all_scores[4]))} times of {all_scores.shape[1]} rounds")
print(f"the level 9 average is {round(np.mean(all_scores[1]),3)} points")
print(f"the level 6 average is {round(np.mean(all_scores[2]),3)} points")
print(f"the level 9 average adventage is  {round(np.mean(all_scores[2]-all_scores[1]),3)} points")
print(f"level 9 wins to {round(np.mean(100-all_scores[4]*100),1)} %")
print(f"level 9 average adventage {round(deltalevel9/(all_scores.shape[1]-sum(all_scores[4])),3)} points")
print(f"level 6 average adventage {round(deltalevel6/(sum(all_scores[4])),3)} points")
# Out:
# level 9 against level 6
# to 83.64 % finishes level 6
# level 9 won 2193 times of 5000 rounds
# the level 9 average is 35.35 points
# the level 6 average is 22.024 points
# the level 9 average adventage is  -13.326 points
# level 9 wins to 43.9 %
# level 9 average adventage 12.545 points
# level 6 average adventage 33.538 points

# %%
all_scores2_a=np.loadtxt("level11_level6_500_0.txt")
all_scores2_b=np.loadtxt("level11_level6_1500_0.txt")
all_scores2_c=np.loadtxt("level11_level6_3000_0.txt")
all_scores2=np.zeros((7,5000))
all_scores2[:,0:500]=all_scores2_a
all_scores2[:,500:2000]=all_scores2_b
all_scores2[:,2000:5000]=all_scores2_c
deltalevel11=0
deltalevel6=0
for i in range(all_scores2.shape[1]):
    if all_scores2[1,i]<all_scores2[2,i]:
        #to calculate by how much a  human wins in average 
        deltalevel11+=(all_scores2[2,i]-all_scores2[1,i])
    else:
        deltalevel6+=(all_scores2[1,i]-all_scores2[2,i])
print("level 11 against level 6")
print(f"to {np.round(np.mean(all_scores2[6])*100,3)} % finishes level 6")
print(f"level 11 won {int(all_scores2.shape[1]-sum(all_scores2[4]))} times of {all_scores2.shape[1]} rounds")
print(f"the level 11 average is {round(np.mean(all_scores2[1]),3)} points")
print(f"the level 6 average is {round(np.mean(all_scores2[2]),3)} points")
print(f"the level 11 average adventage is  {round(np.mean(all_scores2[2]-all_scores2[1]),3)} points")
print(f"level 11 wins to {round(np.mean(100-all_scores2[4]*100),1)} %")
print(f"level 11 average adventage {round(deltalevel11/(all_scores2.shape[1]-sum(all_scores2[4])),3)} points")
print(f"level 6 average adventage {round(deltalevel6/(sum(all_scores2[4])),3)} points")
# Out:
# level 11 against level 6
# to 87.62 % finishes level 6
# level 11 won 2237 times of 5000 rounds
# the level 11 average is 35.235 points
# the level 6 average is 21.885 points
# the level 11 average adventage is  -13.35 points
# level 11 wins to 44.7 %
# level 11 average adventage 12.761 points
# level 6 average adventage 34.49 points

# %% [markdown]
# The human imitation level (9) performs somehwhat worse than level 6, clearer in the points than in the win fraction.
#
# Level 11 performs very similar, slightly more wins but with worse losses.
#
# Still the more important metric is compared to humans.
